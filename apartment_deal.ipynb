# %%
import pandas as pd
import os


dir_path = "dataset\\deal_price\\Seoul"
file_list = os.listdir(dir_path)
df_list = list()

# 해당 폴더 안에 있는 csv 파일들을 읽어서 리스트 안에 데이터프레임들을 담음
for csv_file in file_list:
    df_list.append(pd.read_csv(dir_path+"\\"+csv_file ,skiprows=15,  encoding='cp949'))

# %%
df_list[1].info() # 리스트 안에 잘 담겼는지 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59011 entries, 0 to 59010
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시군구       59011 non-null  object
#  1   번지        59011 non-null  object
#  2   본번        59011 non-null  int64
#  3   부번        59011 non-null  int64
#  4   단지명       59011 non-null  object
#  5   전용면적(㎡)   59011 non-null  float64
#  6   계약년월      59011 non-null  int64
#  7   계약일       59011 non-null  int64
#  8   거래금액(만원)  59011 non-null  object
#  9   층         59011 non-null  int64
#  10  건축년도      59011 non-null  int64
#  11  도로명       59011 non-null  object
#  12  해제사유발생일   0 non-null      float64
#  13  거래유형      59011 non-null  object
#  14  중개사소재지    59011 non-null  object
# dtypes: float64(2), int64(6), object(7)
# memory usage: 6.8+ MB

# %%
# 모든 데이터프레임을을 통합
df_default = df_list[0]
for df_csv in df_list[1:]:
    df_default = pd.concat([df_default, df_csv], axis=0)
df_default.loc[1] # 여러 데이터프레임들을 바로 합친거여서 인덱스가 겹치는 것들이 생김
# Out:
#              시군구     번지     본번   부번             단지명  전용면적(㎡)    계약년월  계약일  \
# 1  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  200603   29
# 1  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  200703    9
# 1  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  200812   11
# 1  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  200902    9
# 1  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  201008    5
# 1  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  201107   28
# 1  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  201207    9
# 1  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  201312   16
# 1  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  201411   10
# 1  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  201503    3
# 1  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  201604    2
# 1  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  201704   19
# 1  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  201801    8
# 1  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  201911   18
# 1  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    54.98  202002   24
# 1  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202105   15
# 1  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202204   21
#
#   거래금액(만원)  층    건축년도      도로명  해제사유발생일  거래유형  중개사소재지
# 1   60,000  6  1988.0  언주로 103      NaN     -       -
# 1   93,000  2  1987.0    언주로 3      NaN     -       -
# 1   80,000  3  1988.0  언주로 103      NaN     -       -
# 1   74,000  2  1987.0    언주로 3      NaN     -       -
# 1   80,600  5  1987.0    언주로 3      NaN     -       -
# 1   65,500  5  1988.0  언주로 103      NaN     -       -
# 1   58,000  2  1988.0  언주로 103      NaN     -       -
# 1   57,000  2  1988.0  언주로 103      NaN     -       -
# 1   59,500  4  1988.0  언주로 103      NaN     -       -
# 1   65,000  5  1988.0  언주로 103      NaN     -       -
# 1   71,000  2  1988.0  언주로 103      NaN     -       -
# 1   85,000  2  1988.0  언주로 103      NaN     -       -
# 1  117,000  2  1987.0    언주로 3      NaN     -       -
# 1  160,000  2  1988.0  언주로 103      NaN     -       -
# 1  144,000  4  1987.0    언주로 3      NaN     -       -
# 1  195,000  5  1987.0    언주로 3      NaN     -       -
# 1  220,000  2  1987.0    언주로 3      NaN  중개거래  서울 강남구

# %%
# 인덱스를 따로 설정
df_default.index = [x for x in range(1, len(df_default.values)+1)]
df_default.loc[1]
# Out:
# 시군구          서울특별시 강남구 개포동
# 번지                   655-2
# 본번                   655.0
# 부번                     2.0
# 단지명         개포2차현대아파트(220)
# 전용면적(㎡)              77.75
# 계약년월                200603
# 계약일                     10
# 거래금액(만원)            59,500
# 층                        7
# 건축년도                1988.0
# 도로명                언주로 103
# 해제사유발생일                NaN
# 거래유형                     -
# 중개사소재지                   -
# Name: 1, dtype: object

# %%
df_default.head() # 기본 정보 파악
# Out:
#              시군구     번지     본번   부번             단지명  전용면적(㎡)    계약년월  계약일  \
# 1  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  200603   10
# 2  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  200603   29
# 3  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  200604   29
# 4  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  200606    1
# 5  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  200610   20
#
#   거래금액(만원)  층    건축년도      도로명  해제사유발생일 거래유형 중개사소재지
# 1   59,500  7  1988.0  언주로 103      NaN    -      -
# 2   60,000  6  1988.0  언주로 103      NaN    -      -
# 3   67,000  9  1988.0  언주로 103      NaN    -      -
# 4   60,000  4  1988.0  언주로 103      NaN    -      -
# 5   72,250  5  1988.0  언주로 103      NaN    -      -

# %%
df_default.info() # 데이터프레임 합친 결과 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1237491 entries, 1 to 1237491
# Data columns (total 15 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   시군구       1237491 non-null  object
#  1   번지        1237270 non-null  object
#  2   본번        1237416 non-null  float64
#  3   부번        1237416 non-null  float64
#  4   단지명       1237491 non-null  object
#  5   전용면적(㎡)   1237491 non-null  float64
#  6   계약년월      1237491 non-null  int64
#  7   계약일       1237491 non-null  int64
#  8   거래금액(만원)  1237491 non-null  object
#  9   층         1237491 non-null  int64
#  10  건축년도      1237489 non-null  float64
#  11  도로명       1237491 non-null  object
#  12  해제사유발생일   5242 non-null     float64
#  13  거래유형      1237491 non-null  object
#  14  중개사소재지    1237491 non-null  object
# dtypes: float64(5), int64(3), object(7)
# memory usage: 151.1+ MB

# %%
# 사용할 컬럼들만 거르고 컬럼명 영어로 치환 - null 값이 없는 컬럼들만 선택
# 번지, 본번, 부번은 null 값들이 있음
df_default = df_default[['시군구','본번','부번','도로명','단지명','계약년월','계약일','거래금액(만원)','층']]
df_default.columns = ['address','main_number','sub_number','road','name','year_month','day','deal_price','floor']
df_default.head() # 잘 걸러졌는지 확인
# Out:
#          address  main_number  sub_number     road            name  \
# 1  서울특별시 강남구 개포동        655.0         2.0  언주로 103  개포2차현대아파트(220)
# 2  서울특별시 강남구 개포동        655.0         2.0  언주로 103  개포2차현대아파트(220)
# 3  서울특별시 강남구 개포동        655.0         2.0  언주로 103  개포2차현대아파트(220)
# 4  서울특별시 강남구 개포동        655.0         2.0  언주로 103  개포2차현대아파트(220)
# 5  서울특별시 강남구 개포동        655.0         2.0  언주로 103  개포2차현대아파트(220)
#
#    year_month  day deal_price  floor
# 1      200603   10     59,500      7
# 2      200603   29     60,000      6
# 3      200604   29     67,000      9
# 4      200606    1     60,000      4
# 5      200610   20     72,250      5

# %%
# 타입 변경을 통해서 year_month, day 타입 str로 변경
df_default["deal_price"] = df_default["deal_price"].str.replace(",", "")
df = df_default.astype({'year_month':'str','day':'str','deal_price':'int64'}).copy()
df.head() # 형태가 변경된거 확인
# Out:
#          address  main_number  sub_number     road            name year_month  \
# 1  서울특별시 강남구 개포동        655.0         2.0  언주로 103  개포2차현대아파트(220)     200603
# 2  서울특별시 강남구 개포동        655.0         2.0  언주로 103  개포2차현대아파트(220)     200603
# 3  서울특별시 강남구 개포동        655.0         2.0  언주로 103  개포2차현대아파트(220)     200604
# 4  서울특별시 강남구 개포동        655.0         2.0  언주로 103  개포2차현대아파트(220)     200606
# 5  서울특별시 강남구 개포동        655.0         2.0  언주로 103  개포2차현대아파트(220)     200610
#
#   day  deal_price  floor
# 1  10       59500      7
# 2  29       60000      6
# 3  29       67000      9
# 4   1       60000      4
# 5  20       72250      5

# %%
df.info() # 타입 및 null 확인 -> main_number와 sub_number에 null 값들이 있다
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1237491 entries, 1 to 1237491
# Data columns (total 9 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   address      1237491 non-null  object
#  1   main_number  1237416 non-null  float64
#  2   sub_number   1237416 non-null  float64
#  3   road         1237491 non-null  object
#  4   name         1237491 non-null  object
#  5   year_month   1237491 non-null  object
#  6   day          1237491 non-null  object
#  7   deal_price   1237491 non-null  int64
#  8   floor        1237491 non-null  int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 94.4+ MB

# %%
# 'main_number'혹은 'sub_number'이 null 인데 'road'도 null 인 값을 확인 -> 없음
# 즉, 'road가 정보가 더욱 많음'
df[((df['main_number'].isnull()) |(df['sub_number'].isnull())) &(df['road'].isnull()) ]
# Out:
# Empty DataFrame
# Columns: [address, main_number, sub_number, road, name, year_month, day, deal_price, floor]
# Index: []

# %%
# 연도 및 날짜 분리 및 생성
df['year'] = df['year_month'].str[0:4] # 연,월 합쳐져 있는 컬럼에서 연도만 추출
df['month'] = df['year_month'].str[4:] # 연,월 합쳐져 있는 컬럼에서 월만 추출
df.loc[df["day"].str.len()==1,"day"]='0'+df.loc[df["day"].str.len()==1,"day"] # 일이 있는 컬럼에서 1자리 숫자인 경우 앞에 0을 추가
df['date'] = pd.to_datetime(df['year']+df['month']+df['day']) # 일자들을 합쳐서 date 컬럼 생성
df = df.drop(['year_month'], axis=1) # 사용 안하는 컬럼들 제거
df.head()
# Out:
#          address  main_number  sub_number     road            name day  \
# 1  서울특별시 강남구 개포동        655.0         2.0  언주로 103  개포2차현대아파트(220)  10
# 2  서울특별시 강남구 개포동        655.0         2.0  언주로 103  개포2차현대아파트(220)  29
# 3  서울특별시 강남구 개포동        655.0         2.0  언주로 103  개포2차현대아파트(220)  29
# 4  서울특별시 강남구 개포동        655.0         2.0  언주로 103  개포2차현대아파트(220)  01
# 5  서울특별시 강남구 개포동        655.0         2.0  언주로 103  개포2차현대아파트(220)  20
#
#    deal_price  floor  year month       date
# 1       59500      7  2006    03 2006-03-10
# 2       60000      6  2006    03 2006-03-29
# 3       67000      9  2006    04 2006-04-29
# 4       60000      4  2006    06 2006-06-01
# 5       72250      5  2006    10 2006-10-20

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1237491 entries, 1 to 1237491
# Data columns (total 11 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   address      1237491 non-null  object
#  1   main_number  1237416 non-null  float64
#  2   sub_number   1237416 non-null  float64
#  3   road         1237491 non-null  object
#  4   name         1237491 non-null  object
#  5   day          1237491 non-null  object
#  6   deal_price   1237491 non-null  int64
#  7   floor        1237491 non-null  int64
#  8   year         1237491 non-null  object
#  9   month        1237491 non-null  object
#  10  date         1237491 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(2), object(6)
# memory usage: 113.3+ MB

# %%
# 주소 및 도로명들 분리
df["address_0"] = df["address"].str.split(' ',expand=True)[0] # '시' 만 추출해야 하나, 서울만 함으로 일단은 실행 X
df["address_1"] = df["address"].str.split(' ',expand=True)[1] # '구' 만 추출
df["address_2"] = df["address"].str.split(' ',expand=True)[2] # '동' 만 추출
df["road_name"] = df["road"].str.split(' ',expand=True)[0] # '도로명' 만 추출
df["road_number"] = df["road"].str.split(' ',expand=True)[1] # '도로숫자' 만 추출
df= df[['date','address_0','address_1','address_2','road_name','road_number','floor','deal_price','name','main_number','sub_number']] # 사용할 컬럼만 선택
df.head()
# Out:
#         date address_0 address_1 address_2 road_name road_number  floor  \
# 1 2006-03-10     서울특별시       강남구       개포동       언주로         103      7
# 2 2006-03-29     서울특별시       강남구       개포동       언주로         103      6
# 3 2006-04-29     서울특별시       강남구       개포동       언주로         103      9
# 4 2006-06-01     서울특별시       강남구       개포동       언주로         103      4
# 5 2006-10-20     서울특별시       강남구       개포동       언주로         103      5
#
#    deal_price            name  main_number  sub_number
# 1       59500  개포2차현대아파트(220)        655.0         2.0
# 2       60000  개포2차현대아파트(220)        655.0         2.0
# 3       67000  개포2차현대아파트(220)        655.0         2.0
# 4       60000  개포2차현대아파트(220)        655.0         2.0
# 5       72250  개포2차현대아파트(220)        655.0         2.0

# %%
df.info() # road_number에 null 값이 생김을 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1237491 entries, 1 to 1237491
# Data columns (total 11 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   date         1237491 non-null  datetime64[ns]
#  1   address_0    1237491 non-null  object
#  2   address_1    1237491 non-null  object
#  3   address_2    1237491 non-null  object
#  4   road_name    1237491 non-null  object
#  5   road_number  1237490 non-null  object
#  6   floor        1237491 non-null  int64
#  7   deal_price   1237491 non-null  int64
#  8   name         1237491 non-null  object
#  9   main_number  1237416 non-null  float64
#  10  sub_number   1237416 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(6)
# memory usage: 113.3+ MB

# %%
df[df['road_number'].isnull()] # road_number에 null값이 들어 있는 row를 확인
# Out:
#               date address_0 address_1 address_2 road_name road_number  floor  \
# 1177516 2020-12-31     서울특별시        중구     만리동2가      만리재로        None      2
#
#          deal_price          name  main_number  sub_number
# 1177516      161000  서울역센트럴자이(임대)        176.0         1.0

# %%
# '서울역센트럴자이'를 확인 -> '' 값이 존재함을 확인..
df.loc[df['name'] == '서울역센트럴자이',:]
# Out:
#               date address_0 address_1 address_2 road_name road_number  floor  \
# 936224  2017-05-03     서울특별시        중구     만리동2가      만리재로         175      6
# 936225  2017-12-20     서울특별시        중구     만리동2가      만리재로         175     13
# 936226  2017-12-30     서울특별시        중구     만리동2가                           17
# 1018068 2018-03-20     서울특별시        중구     만리동2가                           17
# 1093939 2019-07-13     서울특별시        중구     만리동2가      만리재로         175     13
# 1093940 2019-08-20     서울특별시        중구     만리동2가      만리재로         175      8
# 1093941 2019-08-23     서울특별시        중구     만리동2가      만리재로         175     15
# 1093942 2019-09-08     서울특별시        중구     만리동2가      만리재로         175     11
# 1093943 2019-09-21     서울특별시        중구     만리동2가      만리재로         175     24
# 1093944 2019-11-30     서울특별시        중구     만리동2가      만리재로         175     23
# 1093945 2019-12-12     서울특별시        중구     만리동2가      만리재로         175      2
# 1093946 2019-12-14     서울특별시        중구     만리동2가      만리재로         175      6
# 1177511 2020-01-08     서울특별시        중구     만리동2가      만리재로         175      6
# 1177512 2020-05-20     서울특별시        중구     만리동2가      만리재로         175     22
# 1177513 2020-07-12     서울특별시        중구     만리동2가      만리재로         175      1
# 1177514 2020-08-13     서울특별시        중구     만리동2가      만리재로         175     12
# 1177515 2020-10-17     서울특별시        중구     만리동2가      만리재로         175      1
# 1222611 2021-12-14     서울특별시        중구     만리동2가      만리재로         175     14
# 1236742 2022-01-17     서울특별시        중구     만리동2가      만리재로         175      4
# 1236743 2022-03-02     서울특별시        중구     만리동2가      만리재로         175     20
# 1236744 2022-06-05     서울특별시        중구     만리동2가      만리재로         175     10
# 1236745 2022-12-14     서울특별시        중구     만리동2가      만리재로         175      9
#
#          deal_price      name  main_number  sub_number
# 936224        79390  서울역센트럴자이        176.0         1.0
# 936225        85000  서울역센트럴자이        176.0         1.0
# 936226        85000  서울역센트럴자이        176.0         1.0
# 1018068       85000  서울역센트럴자이        176.0         1.0
# 1093939      134500  서울역센트럴자이        176.0         1.0
# 1093940       95000  서울역센트럴자이        176.0         1.0
# 1093941      139000  서울역센트럴자이        176.0         1.0
# 1093942      113800  서울역센트럴자이        176.0         1.0
# 1093943      132000  서울역센트럴자이        176.0         1.0
# 1093944      120000  서울역센트럴자이        176.0         1.0
# 1093945      136500  서울역센트럴자이        176.0         1.0
# 1093946      141000  서울역센트럴자이        176.0         1.0
# 1177511      141500  서울역센트럴자이        176.0         1.0
# 1177512      133500  서울역센트럴자이        176.0         1.0
# 1177513      142000  서울역센트럴자이        176.0         1.0
# 1177514      158000  서울역센트럴자이        176.0         1.0
# 1177515      136500  서울역센트럴자이        176.0         1.0
# 1222611      183000  서울역센트럴자이        176.0         1.0
# 1236742      170000  서울역센트럴자이        176.0         1.0
# 1236743      179500  서울역센트럴자이        176.0         1.0
# 1236744      148750  서울역센트럴자이        176.0         1.0
# 1236745      145000  서울역센트럴자이        176.0         1.0

# %% [markdown]
# >> null 값이 없다고 ''값도 없는건 아니구나!

# %%
df.loc[df['name'] == '서울역센트럴자이(임대)','name']='서울역센트럴자이' # '서울역센트럴자이(임대)' 명칭 '서울역센트럴자이'로 수정
df.loc[df['name'] == '서울역센트럴자이','road_name']='만리재로' # 위에서 확인한 값들로 'road_name' 수정
df.loc[df['name'] == '서울역센트럴자이','road_number']='175' # 위에서 확인한 값들로 'road_number' 수정
df.info() # 우선 1차적으로 null 값들은 처리함을 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1237491 entries, 1 to 1237491
# Data columns (total 11 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   date         1237491 non-null  datetime64[ns]
#  1   address_0    1237491 non-null  object
#  2   address_1    1237491 non-null  object
#  3   address_2    1237491 non-null  object
#  4   road_name    1237491 non-null  object
#  5   road_number  1237491 non-null  object
#  6   floor        1237491 non-null  int64
#  7   deal_price   1237491 non-null  int64
#  8   name         1237491 non-null  object
#  9   main_number  1237416 non-null  float64
#  10  sub_number   1237416 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(6)
# memory usage: 113.3+ MB

# %% [markdown]
# >> 앞에서 과정들을 통해서 ''들이 값들로 들어 있을 수도 있음을 깨달음

# %%
df = df.replace('', None) # ''값만 있는 값들을 null 값들로 수정
df.info() # 수정한 후 정보 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1237491 entries, 1 to 1237491
# Data columns (total 11 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   date         1237491 non-null  datetime64[ns]
#  1   address_0    1237491 non-null  object
#  2   address_1    1237491 non-null  object
#  3   address_2    1237491 non-null  object
#  4   road_name    1235462 non-null  object
#  5   road_number  1234196 non-null  object
#  6   floor        1237491 non-null  int64
#  7   deal_price   1237491 non-null  int64
#  8   name         1237491 non-null  object
#  9   main_number  1237416 non-null  float64
#  10  sub_number   1237416 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(6)
# memory usage: 113.3+ MB

# %%
df.isnull().sum() # df의 null 값들이 증가함을 확인, 
                  # 처음에는 도로주소가 null값이 더 적은 줄 알았지만, 전처리 과정 중 지번주소가 null 값이 더 적은 듯
# Out:
# date              0
# address_0         0
# address_1         0
# address_2         0
# road_name      2029
# road_number    3295
# floor             0
# deal_price        0
# name              0
# main_number      75
# sub_number       75
# dtype: int64

# %%
# 'main_number'나 'sub_number' 둘중 하나만 null 인 것을 확인 -> 없음
# 즉, 2개가 동시에 null 값을 가지고 있음
df[((df['main_number'].isnull()) &(df['sub_number'].notnull()))
  |((df['main_number'].notnull()) &(df['sub_number'].isnull()))]
# Out:
# Empty DataFrame
# Columns: [date, address_0, address_1, address_2, road_name, road_number, floor, deal_price, name, main_number, sub_number]
# Index: []

# %%
# 도로명정보에는 null이고 지번주소도 null인 데이터를 확인 -> 없다
# 즉, 어떻게든 주소에 대한 정보를 얻을 수 있다
df[((df['road_name'].isnull()) | (df['road_number'].isnull())) & (df['main_number'].isnull())]
# Out:
# Empty DataFrame
# Columns: [date, address_0, address_1, address_2, road_name, road_number, floor, deal_price, name, main_number, sub_number]
# Index: []

# %%
df.loc[df['main_number'].isnull(),['address_0','address_1','address_2','road_name','road_number','name','main_number','sub_number']] # 처리해야 할 null 값이 있는 데이터프레임을 조회
# Out:
#         address_0 address_1 address_2 road_name road_number           name  \
# 681634      서울특별시       서초구       신원동     헌릉로8길       10-12  힐스테이트 서초 젠트리스
# 681635      서울특별시       서초구       신원동     헌릉로8길       10-12  힐스테이트 서초 젠트리스
# 681636      서울특별시       서초구       신원동     헌릉로8길       10-12  힐스테이트 서초 젠트리스
# 681637      서울특별시       서초구       신원동     헌릉로8길       10-12  힐스테이트 서초 젠트리스
# 681638      서울특별시       서초구       신원동     헌릉로8길       10-12  힐스테이트 서초 젠트리스
# ...           ...       ...       ...       ...         ...            ...
# 1209123     서울특별시       서초구       신원동     헌릉로8길       10-12  힐스테이트 서초 젠트리스
# 1209124     서울특별시       서초구       신원동     헌릉로8길       10-12  힐스테이트 서초 젠트리스
# 1209125     서울특별시       서초구       신원동     헌릉로8길       10-12  힐스테이트 서초 젠트리스
# 1232881     서울특별시       서초구       신원동     헌릉로8길       10-12  힐스테이트 서초 젠트리스
# 1232882     서울특별시       서초구       신원동     헌릉로8길       10-12  힐스테이트 서초 젠트리스
#
#          main_number  sub_number
# 681634           NaN         NaN
# 681635           NaN         NaN
# 681636           NaN         NaN
# 681637           NaN         NaN
# 681638           NaN         NaN
# ...              ...         ...
# 1209123          NaN         NaN
# 1209124          NaN         NaN
# 1209125          NaN         NaN
# 1232881          NaN         NaN
# 1232882          NaN         NaN
#
# [75 rows x 8 columns]

# %%
df.loc[df['main_number'].isnull(),'name'].unique() # 처리해야 할 지번주소에 null 값이 있는 아파트명들 조회
                                                   # '힐스테이트 서초 젠트리스'만 수정하면 될듯
# Out:
# array(['힐스테이트 서초 젠트리스'], dtype=object)

# %%
df.loc[df['name']=='힐스테이트 서초 젠트리스',:] # 기존 '힐스테이트 서초 젠트리스' 전체도 지번주소가 null값으로 되어 있음
# Out:
#               date address_0 address_1 address_2 road_name road_number  floor  \
# 681634  2015-03-01     서울특별시       서초구       신원동     헌릉로8길       10-12      5
# 681635  2015-04-17     서울특별시       서초구       신원동     헌릉로8길       10-12      9
# 681636  2015-05-01     서울특별시       서초구       신원동     헌릉로8길       10-12      6
# 681637  2015-06-16     서울특별시       서초구       신원동     헌릉로8길       10-12      6
# 681638  2015-06-26     서울특별시       서초구       신원동     헌릉로8길       10-12      8
# ...            ...       ...       ...       ...       ...         ...    ...
# 1209123 2021-04-27     서울특별시       서초구       신원동     헌릉로8길       10-12      3
# 1209124 2021-05-26     서울특별시       서초구       신원동     헌릉로8길       10-12      4
# 1209125 2021-07-26     서울특별시       서초구       신원동     헌릉로8길       10-12      7
# 1232881 2022-06-23     서울특별시       서초구       신원동     헌릉로8길       10-12      5
# 1232882 2022-09-28     서울특별시       서초구       신원동     헌릉로8길       10-12      8
#
#          deal_price           name  main_number  sub_number
# 681634        73430  힐스테이트 서초 젠트리스          NaN         NaN
# 681635        79000  힐스테이트 서초 젠트리스          NaN         NaN
# 681636        95000  힐스테이트 서초 젠트리스          NaN         NaN
# 681637        87200  힐스테이트 서초 젠트리스          NaN         NaN
# 681638        94500  힐스테이트 서초 젠트리스          NaN         NaN
# ...             ...            ...          ...         ...
# 1209123      184500  힐스테이트 서초 젠트리스          NaN         NaN
# 1209124      165000  힐스테이트 서초 젠트리스          NaN         NaN
# 1209125      182000  힐스테이트 서초 젠트리스          NaN         NaN
# 1232881      204000  힐스테이트 서초 젠트리스          NaN         NaN
# 1232882      173000  힐스테이트 서초 젠트리스          NaN         NaN
#
# [75 rows x 11 columns]

# %%
# 지번주소 null 값들을 검색하여서 정보를 얻고 수정
df.loc[df['name']=='힐스테이트 서초 젠트리스','main_number'] = 557
df.loc[df['name']=='힐스테이트 서초 젠트리스','sub_number'] = 0

# %%
# 사용할 컬럼들과, 컬럼명들 수정
df_deal = df[['date','address_0','address_1','address_2','main_number','sub_number','name','floor','deal_price']].copy()
df_deal.columns =['date','address_0','address_1','address_2','address_3','address_4','name','floor','deal_price']
df_deal.head()
# Out:
#         date address_0 address_1 address_2  address_3  address_4  \
# 1 2006-03-10     서울특별시       강남구       개포동      655.0        2.0
# 2 2006-03-29     서울특별시       강남구       개포동      655.0        2.0
# 3 2006-04-29     서울특별시       강남구       개포동      655.0        2.0
# 4 2006-06-01     서울특별시       강남구       개포동      655.0        2.0
# 5 2006-10-20     서울특별시       강남구       개포동      655.0        2.0
#
#              name  floor  deal_price
# 1  개포2차현대아파트(220)      7       59500
# 2  개포2차현대아파트(220)      6       60000
# 3  개포2차현대아파트(220)      9       67000
# 4  개포2차현대아파트(220)      4       60000
# 5  개포2차현대아파트(220)      5       72250

# %%
df_deal.info() # 데이터프레임 정보 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1237491 entries, 1 to 1237491
# Data columns (total 9 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   date        1237491 non-null  datetime64[ns]
#  1   address_0   1237491 non-null  object
#  2   address_1   1237491 non-null  object
#  3   address_2   1237491 non-null  object
#  4   address_3   1237491 non-null  float64
#  5   address_4   1237491 non-null  float64
#  6   name        1237491 non-null  object
#  7   floor       1237491 non-null  int64
#  8   deal_price  1237491 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 94.4+ MB

# %%
df_deal.iloc[200] # 정보들 제대로 있는지 확인
# Out:
# date          2006-04-21 00:00:00
# address_0                   서울특별시
# address_1                     강남구
# address_2                     개포동
# address_3                   141.0
# address_4                     0.0
# name                      개포주공1단지
# floor                           3
# deal_price                  65000
# Name: 201, dtype: object
