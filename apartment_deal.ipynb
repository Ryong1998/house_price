# %%
import pandas as pd
import os


dir_path = "dataset\\deal_price\\Seoul"
file_list = os.listdir(dir_path)
df_list = list()

# 해당 폴더 안에 있는 csv 파일들을 읽어서 리스트 안에 데이터프레임들을 담음
for csv_file in file_list:
    df_list.append(pd.read_csv(dir_path+"\\"+csv_file ,skiprows=15,  encoding='cp949'))

# %%
df_list[1].info() # 리스트 안에 잘 담겼는지 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59011 entries, 0 to 59010
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시군구       59011 non-null  object
#  1   번지        59011 non-null  object
#  2   본번        59011 non-null  int64
#  3   부번        59011 non-null  int64
#  4   단지명       59011 non-null  object
#  5   전용면적(㎡)   59011 non-null  float64
#  6   계약년월      59011 non-null  int64
#  7   계약일       59011 non-null  int64
#  8   거래금액(만원)  59011 non-null  object
#  9   층         59011 non-null  int64
#  10  건축년도      59011 non-null  int64
#  11  도로명       59011 non-null  object
#  12  해제사유발생일   0 non-null      float64
#  13  거래유형      59011 non-null  object
#  14  중개사소재지    59011 non-null  object
# dtypes: float64(2), int64(6), object(7)
# memory usage: 6.8+ MB

# %%
# 모든 데이터프레임을을 통합
df_default = df_list[0]
for df_csv in df_list[1:]:
    df_default = pd.concat([df_default, df_csv], axis=0)

# %%
df_default.info() # 데이터프레임 합친 결과 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1237491 entries, 0 to 12624
# Data columns (total 15 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   시군구       1237491 non-null  object
#  1   번지        1237270 non-null  object
#  2   본번        1237416 non-null  float64
#  3   부번        1237416 non-null  float64
#  4   단지명       1237491 non-null  object
#  5   전용면적(㎡)   1237491 non-null  float64
#  6   계약년월      1237491 non-null  int64
#  7   계약일       1237491 non-null  int64
#  8   거래금액(만원)  1237491 non-null  object
#  9   층         1237491 non-null  int64
#  10  건축년도      1237489 non-null  float64
#  11  도로명       1237491 non-null  object
#  12  해제사유발생일   5242 non-null     float64
#  13  거래유형      1237491 non-null  object
#  14  중개사소재지    1237491 non-null  object
# dtypes: float64(5), int64(3), object(7)
# memory usage: 151.1+ MB

# %%
df_default.head() # 기본 정보 파악
# Out:
#              시군구     번지     본번   부번             단지명  전용면적(㎡)    계약년월  계약일  \
# 0  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  200603   10
# 1  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  200603   29
# 2  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  200604   29
# 3  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  200606    1
# 4  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  200610   20
#
#   거래금액(만원)  층    건축년도      도로명  해제사유발생일 거래유형 중개사소재지
# 0   59,500  7  1988.0  언주로 103      NaN    -      -
# 1   60,000  6  1988.0  언주로 103      NaN    -      -
# 2   67,000  9  1988.0  언주로 103      NaN    -      -
# 3   60,000  4  1988.0  언주로 103      NaN    -      -
# 4   72,250  5  1988.0  언주로 103      NaN    -      -

# %%
# 사용할 컬럼들만 거르고 컬럼명 영어로 치환
# 번지, 본번, 부번은 null 값들이 있으므로 도로명을 가져옴
df_default = df_default[['시군구','도로명','단지명','계약년월','계약일','거래금액(만원)','층']]
df_default.columns = ['address','road','name','year_month','day','deal_price','floor']
df_default.head()
# Out:
#          address     road            name  year_month  day deal_price  floor
# 0  서울특별시 강남구 개포동  언주로 103  개포2차현대아파트(220)      200603   10     59,500      7
# 1  서울특별시 강남구 개포동  언주로 103  개포2차현대아파트(220)      200603   29     60,000      6
# 2  서울특별시 강남구 개포동  언주로 103  개포2차현대아파트(220)      200604   29     67,000      9
# 3  서울특별시 강남구 개포동  언주로 103  개포2차현대아파트(220)      200606    1     60,000      4
# 4  서울특별시 강남구 개포동  언주로 103  개포2차현대아파트(220)      200610   20     72,250      5

# %%
# 타입 변경을 통해서 year_month, day 타입 str로 변경
df_default["deal_price"] = df_default["deal_price"].str.replace(",", "")
df = df_default.astype({'year_month':'str','day':'str','deal_price':'int64'}).copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1237491 entries, 0 to 12624
# Data columns (total 7 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   address     1237491 non-null  object
#  1   road        1237491 non-null  object
#  2   name        1237491 non-null  object
#  3   year_month  1237491 non-null  object
#  4   day         1237491 non-null  object
#  5   deal_price  1237491 non-null  int64
#  6   floor       1237491 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 75.5+ MB

# %%
df.head()
# Out:
#          address     road            name year_month day  deal_price  floor
# 0  서울특별시 강남구 개포동  언주로 103  개포2차현대아파트(220)     200603  10       59500      7
# 1  서울특별시 강남구 개포동  언주로 103  개포2차현대아파트(220)     200603  29       60000      6
# 2  서울특별시 강남구 개포동  언주로 103  개포2차현대아파트(220)     200604  29       67000      9
# 3  서울특별시 강남구 개포동  언주로 103  개포2차현대아파트(220)     200606   1       60000      4
# 4  서울특별시 강남구 개포동  언주로 103  개포2차현대아파트(220)     200610  20       72250      5

# %%
# 연도 및 날짜 분리 및 생성
df['year'] = df['year_month'].str[0:4] # 연,월 합쳐져 있는 컬럼에서 연도만 추출
df['month'] = df['year_month'].str[4:] # 연,월 합쳐져 있는 컬럼에서 월만 추출
df.loc[df["day"].str.len()==1,"day"]='0'+df.loc[df["day"].str.len()==1,"day"] # 일이 있는 컬럼에서 1자리 숫자인 경우 앞에 0을 추가
df['date'] = pd.to_datetime(df['year']+df['month']+df['day']) # 일자들을 합쳐서 date 컬럼 생성
df = df.drop(['year_month'], axis=1) # 사용 안하는 컬럼들 제거
df.head()
# Out:
#          address     road            name day  deal_price  floor  year month  \
# 0  서울특별시 강남구 개포동  언주로 103  개포2차현대아파트(220)  10       59500      7  2006    03
# 1  서울특별시 강남구 개포동  언주로 103  개포2차현대아파트(220)  29       60000      6  2006    03
# 2  서울특별시 강남구 개포동  언주로 103  개포2차현대아파트(220)  29       67000      9  2006    04
# 3  서울특별시 강남구 개포동  언주로 103  개포2차현대아파트(220)  01       60000      4  2006    06
# 4  서울특별시 강남구 개포동  언주로 103  개포2차현대아파트(220)  20       72250      5  2006    10
#
#         date
# 0 2006-03-10
# 1 2006-03-29
# 2 2006-04-29
# 3 2006-06-01
# 4 2006-10-20

# %%
# 주소 및 도로명들 분리
df["address_0"] = df["address"].str.split(' ',expand=True)[0] # '시' 만 추출해야 하나, 서울만 함으로 일단은 실행 X
df["address_1"] = df["address"].str.split(' ',expand=True)[1] # '구' 만 추출
df["address_2"] = df["address"].str.split(' ',expand=True)[2] # '동' 만 추출
df["road_name"] = df["road"].str.split(' ',expand=True)[0] # '도로명' 만 추출
df["road_number"] = df["road"].str.split(' ',expand=True)[1] # '도로숫자' 만 추출
df= df[['date','address_1','address_2','road_name','road_number','floor','deal_price','name']] # 사용할 컬럼만 선택
df.head()
# Out:
#         date address_1 address_2 road_name road_number  floor  deal_price  \
# 0 2006-03-10       강남구       개포동       언주로         103      7       59500
# 1 2006-03-29       강남구       개포동       언주로         103      6       60000
# 2 2006-04-29       강남구       개포동       언주로         103      9       67000
# 3 2006-06-01       강남구       개포동       언주로         103      4       60000
# 4 2006-10-20       강남구       개포동       언주로         103      5       72250
#
#              name
# 0  개포2차현대아파트(220)
# 1  개포2차현대아파트(220)
# 2  개포2차현대아파트(220)
# 3  개포2차현대아파트(220)
# 4  개포2차현대아파트(220)

# %%
df.info() # road_number에 null 값이 있음을 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1237491 entries, 0 to 12624
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   date         1237491 non-null  datetime64[ns]
#  1   address_1    1237491 non-null  object
#  2   address_2    1237491 non-null  object
#  3   road_name    1237491 non-null  object
#  4   road_number  1237490 non-null  object
#  5   floor        1237491 non-null  int64
#  6   deal_price   1237491 non-null  int64
#  7   name         1237491 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 85.0+ MB

# %%
# road_number가 빈 값인 row 출력 -> '서울역센트럴자이(임대)'가 road_number가 none 이므로'서울역센트럴자이'를 확인
df.loc[df['road_number'].isnull(),:]
# Out:
#             date address_1 address_2 road_name road_number  floor  deal_price  \
# 80237 2020-12-31        중구     만리동2가      만리재로        None      2      161000
#
#                name
# 80237  서울역센트럴자이(임대)

# %%
# '서울역센트럴자이'를 확인 -> '' 값이 존재함을 확인..
df.loc[df['name'] == '서울역센트럴자이',:]
# Out:
#              date address_1 address_2 road_name road_number  floor  \
# 100795 2017-05-03        중구     만리동2가      만리재로         175      6
# 100796 2017-12-20        중구     만리동2가      만리재로         175     13
# 100797 2017-12-30        중구     만리동2가                           17
# 77533  2018-03-20        중구     만리동2가                           17
# 71745  2019-07-13        중구     만리동2가      만리재로         175     13
# 71746  2019-08-20        중구     만리동2가      만리재로         175      8
# 71747  2019-08-23        중구     만리동2가      만리재로         175     15
# 71748  2019-09-08        중구     만리동2가      만리재로         175     11
# 71749  2019-09-21        중구     만리동2가      만리재로         175     24
# 71750  2019-11-30        중구     만리동2가      만리재로         175     23
# 71751  2019-12-12        중구     만리동2가      만리재로         175      2
# 71752  2019-12-14        중구     만리동2가      만리재로         175      6
# 80232  2020-01-08        중구     만리동2가      만리재로         175      6
# 80233  2020-05-20        중구     만리동2가      만리재로         175     22
# 80234  2020-07-12        중구     만리동2가      만리재로         175      1
# 80235  2020-08-13        중구     만리동2가      만리재로         175     12
# 80236  2020-10-17        중구     만리동2가      만리재로         175      1
# 41195  2021-12-14        중구     만리동2가      만리재로         175     14
# 11875  2022-01-17        중구     만리동2가      만리재로         175      4
# 11876  2022-03-02        중구     만리동2가      만리재로         175     20
# 11877  2022-06-05        중구     만리동2가      만리재로         175     10
# 11878  2022-12-14        중구     만리동2가      만리재로         175      9
#
#         deal_price      name
# 100795       79390  서울역센트럴자이
# 100796       85000  서울역센트럴자이
# 100797       85000  서울역센트럴자이
# 77533        85000  서울역센트럴자이
# 71745       134500  서울역센트럴자이
# 71746        95000  서울역센트럴자이
# 71747       139000  서울역센트럴자이
# 71748       113800  서울역센트럴자이
# 71749       132000  서울역센트럴자이
# 71750       120000  서울역센트럴자이
# 71751       136500  서울역센트럴자이
# 71752       141000  서울역센트럴자이
# 80232       141500  서울역센트럴자이
# 80233       133500  서울역센트럴자이
# 80234       142000  서울역센트럴자이
# 80235       158000  서울역센트럴자이
# 80236       136500  서울역센트럴자이
# 41195       183000  서울역센트럴자이
# 11875       170000  서울역센트럴자이
# 11876       179500  서울역센트럴자이
# 11877       148750  서울역센트럴자이
# 11878       145000  서울역센트럴자이

# %%
df.loc[df['name'] == '서울역센트럴자이(임대)','name']='서울역센트럴자이' # '서울역센트럴자이(임대)' 명칭 '서울역센트럴자이'로 수정
df.loc[df['name'] == '서울역센트럴자이','road_name']='만리재로' # 위에서 확인한 값들로 'road_name' 수정
df.loc[df['name'] == '서울역센트럴자이','road_number']='175' # 위에서 확인한 값들로 'road_number' 수정
df.loc[df['name'] == '서울역센트럴자이',:] # '서울역센트럴자이' 값 수정 됬는지 확인
# Out:
#              date address_1 address_2 road_name road_number  floor  \
# 100795 2017-05-03        중구     만리동2가      만리재로         175      6
# 100796 2017-12-20        중구     만리동2가      만리재로         175     13
# 100797 2017-12-30        중구     만리동2가      만리재로         175     17
# 77533  2018-03-20        중구     만리동2가      만리재로         175     17
# 71745  2019-07-13        중구     만리동2가      만리재로         175     13
# 71746  2019-08-20        중구     만리동2가      만리재로         175      8
# 71747  2019-08-23        중구     만리동2가      만리재로         175     15
# 71748  2019-09-08        중구     만리동2가      만리재로         175     11
# 71749  2019-09-21        중구     만리동2가      만리재로         175     24
# 71750  2019-11-30        중구     만리동2가      만리재로         175     23
# 71751  2019-12-12        중구     만리동2가      만리재로         175      2
# 71752  2019-12-14        중구     만리동2가      만리재로         175      6
# 80232  2020-01-08        중구     만리동2가      만리재로         175      6
# 80233  2020-05-20        중구     만리동2가      만리재로         175     22
# 80234  2020-07-12        중구     만리동2가      만리재로         175      1
# 80235  2020-08-13        중구     만리동2가      만리재로         175     12
# 80236  2020-10-17        중구     만리동2가      만리재로         175      1
# 80237  2020-12-31        중구     만리동2가      만리재로         175      2
# 41195  2021-12-14        중구     만리동2가      만리재로         175     14
# 11875  2022-01-17        중구     만리동2가      만리재로         175      4
# 11876  2022-03-02        중구     만리동2가      만리재로         175     20
# 11877  2022-06-05        중구     만리동2가      만리재로         175     10
# 11878  2022-12-14        중구     만리동2가      만리재로         175      9
#
#         deal_price      name
# 100795       79390  서울역센트럴자이
# 100796       85000  서울역센트럴자이
# 100797       85000  서울역센트럴자이
# 77533        85000  서울역센트럴자이
# 71745       134500  서울역센트럴자이
# 71746        95000  서울역센트럴자이
# 71747       139000  서울역센트럴자이
# 71748       113800  서울역센트럴자이
# 71749       132000  서울역센트럴자이
# 71750       120000  서울역센트럴자이
# 71751       136500  서울역센트럴자이
# 71752       141000  서울역센트럴자이
# 80232       141500  서울역센트럴자이
# 80233       133500  서울역센트럴자이
# 80234       142000  서울역센트럴자이
# 80235       158000  서울역센트럴자이
# 80236       136500  서울역센트럴자이
# 80237       161000  서울역센트럴자이
# 41195       183000  서울역센트럴자이
# 11875       170000  서울역센트럴자이
# 11876       179500  서울역센트럴자이
# 11877       148750  서울역센트럴자이
# 11878       145000  서울역센트럴자이

# %%
# 앞에서 과정들을 통해서 ''들이 값들로 들어 있을 수도 있음을 깨달음
# 컬럼별로 ''을 값으로 가지고 있는지 확인
for column in df.columns:
    if '' in list(df[column].unique()):
        print(column,'수정해야함')
    else:
        pass
# Out:
# road_name 수정해야함
# road_number 수정해야함

# %%
df.loc[(df['road_name']=='') |(df['road_number']==''),:] # 값들이 ''인 row들을 확인
# Out:
#            date address_1 address_2 road_name road_number  floor  deal_price  \
# 1606 2006-02-23       강남구       논현동                            1       73500
# 1628 2006-10-19       강남구       논현동                            7       71000
# 2799 2006-01-24       강남구       대치동                            4       80000
# 2806 2006-02-14       강남구       대치동                            7      143500
# 2807 2006-02-14       강남구       대치동                           10      142000
# ...         ...       ...       ...       ...         ...    ...         ...
# 9199 2022-06-24       송파구       거여동                           14      128000
# 9200 2022-07-21       송파구       거여동                           23      135000
# 9201 2022-07-23       송파구       거여동                            7      125000
# 9203 2022-08-19       송파구       거여동                            9      130000
# 9205 2022-10-07       송파구       거여동                           22      148000
#
#               name
# 1606            경복
# 1628            경복
# 2799           청실1
# 2806           청실1
# 2807           청실1
# ...            ...
# 9199  e편한세상송파파크센트럴
# 9200  e편한세상송파파크센트럴
# 9201  e편한세상송파파크센트럴
# 9203  e편한세상송파파크센트럴
# 9205  e편한세상송파파크센트럴
#
# [3423 rows x 8 columns]

# %%
process_list=list() # 수정할 값들이 단긴 리스트 생성
# 'road_name' 컬럼이 ''인 값이거나 'road_number' 컬럼이 ''인 값들 중에서 아파트명 
for apart_name in list(df.loc[(df['road_name']=='') |(df['road_number']==''),'name'].unique()):
    temp_dict=dict()
    # 해당 아파트명에 대응하는 아파트명 값들 추가
    temp_dict['apartment_name']=apart_name 
    # 해당 아파트명에 대응하는 도로명 값들 추가
    temp_dict['road_name']= list(df.loc[df['name']==apart_name,'road_name'].unique())
    # 해당 아파트명에 대응하는 도로숫자 값들 추가
    temp_dict['road_number']=list(df.loc[df['name']==apart_name,'road_number'].unique())
    process_list.append(temp_dict)
print(process_list)
# Out:
# [{'apartment_name': '경복', 'road_name': ['언주로', ''], 'road_number': ['604', '']}, {'apartment_name': '청실1', 'road_name': ['남부순환로395길', ''], 'road_number': ['11', '']}, {'apartment_name': '청실2', 'road_name': ['남부순환로395길', ''], 'road_number': ['12', '']}, {'apartment_name': '도곡쌍용예가', 'road_name': ['남부순환로363길'], 'road_number': ['', '30']}, {'apartment_name': '진달래', 'road_name': ['', '도곡로', '청구로3길'], 'road_number': ['', '320', '72']}, {'apartment_name': '삼지', 'road_name': [''], 'road_number': ['']}, {'apartment_name': '성보', 'road_name': ['선릉로85길', '', '테헤란로52길', '목동중앙서로'], 'road_number': ['18', '', '16', '47']}, {'apartment_name': '진달래2차', 'road_name': [''], 'road_number': ['']}, {'apartment_name': '진달래3차', 'road_name': [''], 'road_number': ['']}, {'apartment_name': '한양', 'road_name': ['', '동남로71길', '미성5길', '구의강변로', '시흥대로', '동일로216길', '서초중앙로', '잠원로', '삼전로4길', '영등포로86길', '국제금융로'], 'road_number': ['', '19', '33', '11', '165', '92', '220', '62', '4-28', '32', '79']}, {'apartment_name': '삼익가든', 'road_name': ['상암로'], 'road_number': ['224', '225', '']}, {'apartment_name': '현대(고덕)', 'road_name': ['동남로71길'], 'road_number': ['', '41']}, {'apartment_name': '미주', 'road_name': ['성내로', '', '등촌로13자길', '약령시로', '모래내로', '신반포로16길', '필동로5길'], 'road_number': ['74', '', '51', '154', '147', '344-7', '15-20', '2']}, {'apartment_name': '성내1차e-편한세상', 'road_name': ['천호대로168길'], 'road_number': ['58', '51', '']}, {'apartment_name': '유원강변', 'road_name': ['노량진로23가길'], 'road_number': ['20', '']}, {'apartment_name': '유원(1,2차)', 'road_name': [''], 'road_number': ['']}, {'apartment_name': '현대', 'road_name': ['선릉로18길', '천호옛12길', '공항대로45길', '방화대로37길', '대학20길', '개봉로20길', '구로중앙로18길', '석계로', '섬밭로', '한천로58길', '정릉천동로', '약령시로21길', '서울시립대로29길', '여의대방로26길', '사당로17길', '여의대방로', '토정로', '', '성암로7길', '충정로7길', '신반포로3길', '동산로6길', '잠원로12길', '마장로35길', '독서당로40길', '송이로34길', '오금로32길', '백제고분로18길', '목동동로', '신목로', '통일로', '다산로36길', '봉우재로57길', '용마산로', '살곶이길'], 'road_number': ['12', '27', '24', '26', '35', '6', '68', '49', '232', '107', '90', '30', '62', '45', '111', '28', '242', '', '3', '14', '19', '4', '76', '25', '42', '7', '202', '23', '246-20', '246-9', '109', '37-4', '252', '50']}, {'apartment_name': '마포지구시범3동', 'road_name': [''], 'road_number': ['']}, {'apartment_name': '마포지구시범4동', 'road_name': [''], 'road_number': ['']}, {'apartment_name': '마포지구시범5동', 'road_name': [''], 'road_number': ['']}, {'apartment_name': '마포지구시범6동', 'road_name': [''], 'road_number': ['']}, {'apartment_name': '마포지구시범9동', 'road_name': [''], 'road_number': ['']}, {'apartment_name': '반포(주공3)', 'road_name': [''], 'road_number': ['']}, {'apartment_name': '삼호가든맨션(1,2차)', 'road_name': [''], 'road_number': ['']}, {'apartment_name': '한신1차', 'road_name': ['한글비석로46가길', '신반포로15길', ''], 'road_number': ['16', '19', '']}, {'apartment_name': '금호', 'road_name': ['강서로37길', '공원로', '', '뚝섬로5길', '동소문로43길'], 'road_number': ['71', '26', '', '17', '33']}, {'apartment_name': '롯데캐슬쥬피터', 'road_name': ['서운로6길'], 'road_number': ['15-20', '15-13', '']}, {'apartment_name': '롯데캐슬클래식', 'road_name': ['서운로'], 'road_number': ['', '197', '200']}, {'apartment_name': '삼호1차', 'road_name': ['서운로'], 'road_number': ['221', '', '208', '211']}, {'apartment_name': '서초한신', 'road_name': ['남부순환로323길'], 'road_number': ['38-16', '38-15', '']}, {'apartment_name': '세종', 'road_name': ['독산로50다길', '', '세종대로23길'], 'road_number': ['22', '', '54']}, {'apartment_name': '대림', 'road_name': ['남부순환로365길', '공항대로39길', '공항대로75길', '동일로221길', '답십리로60길', '연희로32길', '바우뫼로7길', '잠원로8길', '송이로', '양재대로', '위례성대로', '마천로7길', '신목로5길', '이촌로2가길', '신반포로', '동일로', '논현로41길'], 'road_number': ['16', '100', '42', '22', '38', '20', '51', '', '88', '1109', '176', '4', '9', '122', '45', '1473', '25', '10']}, {'apartment_name': '옥수하이츠', 'road_name': ['한림말길'], 'road_number': ['48', '50', '']}, {'apartment_name': '문화', 'road_name': [''], 'road_number': ['']}, {'apartment_name': '반도1차', 'road_name': [''], 'road_number': ['']}, {'apartment_name': 'A파크', 'road_name': [''], 'road_number': ['']}, {'apartment_na ...

# %%
# 처리할 값들에 대해서 ''요소들 제거
for process in process_list:
    if '' in process['road_name']:
        process['road_name'].remove('')
    if '' in process['road_number']:
        process['road_number'].remove('')
    pass
print(process_list)
# Out:
# [{'apartment_name': '경복', 'road_name': ['언주로'], 'road_number': ['604']}, {'apartment_name': '청실1', 'road_name': ['남부순환로395길'], 'road_number': ['11']}, {'apartment_name': '청실2', 'road_name': ['남부순환로395길'], 'road_number': ['12']}, {'apartment_name': '도곡쌍용예가', 'road_name': ['남부순환로363길'], 'road_number': ['30']}, {'apartment_name': '진달래', 'road_name': ['도곡로', '청구로3길'], 'road_number': ['320', '72']}, {'apartment_name': '삼지', 'road_name': [], 'road_number': []}, {'apartment_name': '성보', 'road_name': ['선릉로85길', '테헤란로52길', '목동중앙서로'], 'road_number': ['18', '16', '47']}, {'apartment_name': '진달래2차', 'road_name': [], 'road_number': []}, {'apartment_name': '진달래3차', 'road_name': [], 'road_number': []}, {'apartment_name': '한양', 'road_name': ['동남로71길', '미성5길', '구의강변로', '시흥대로', '동일로216길', '서초중앙로', '잠원로', '삼전로4길', '영등포로86길', '국제금융로'], 'road_number': ['19', '33', '11', '165', '92', '220', '62', '4-28', '32', '79']}, {'apartment_name': '삼익가든', 'road_name': ['상암로'], 'road_number': ['224', '225']}, {'apartment_name': '현대(고덕)', 'road_name': ['동남로71길'], 'road_number': ['41']}, {'apartment_name': '미주', 'road_name': ['성내로', '등촌로13자길', '약령시로', '모래내로', '신반포로16길', '필동로5길'], 'road_number': ['74', '51', '154', '147', '344-7', '15-20', '2']}, {'apartment_name': '성내1차e-편한세상', 'road_name': ['천호대로168길'], 'road_number': ['58', '51']}, {'apartment_name': '유원강변', 'road_name': ['노량진로23가길'], 'road_number': ['20']}, {'apartment_name': '유원(1,2차)', 'road_name': [], 'road_number': []}, {'apartment_name': '현대', 'road_name': ['선릉로18길', '천호옛12길', '공항대로45길', '방화대로37길', '대학20길', '개봉로20길', '구로중앙로18길', '석계로', '섬밭로', '한천로58길', '정릉천동로', '약령시로21길', '서울시립대로29길', '여의대방로26길', '사당로17길', '여의대방로', '토정로', '성암로7길', '충정로7길', '신반포로3길', '동산로6길', '잠원로12길', '마장로35길', '독서당로40길', '송이로34길', '오금로32길', '백제고분로18길', '목동동로', '신목로', '통일로', '다산로36길', '봉우재로57길', '용마산로', '살곶이길'], 'road_number': ['12', '27', '24', '26', '35', '6', '68', '49', '232', '107', '90', '30', '62', '45', '111', '28', '242', '3', '14', '19', '4', '76', '25', '42', '7', '202', '23', '246-20', '246-9', '109', '37-4', '252', '50']}, {'apartment_name': '마포지구시범3동', 'road_name': [], 'road_number': []}, {'apartment_name': '마포지구시범4동', 'road_name': [], 'road_number': []}, {'apartment_name': '마포지구시범5동', 'road_name': [], 'road_number': []}, {'apartment_name': '마포지구시범6동', 'road_name': [], 'road_number': []}, {'apartment_name': '마포지구시범9동', 'road_name': [], 'road_number': []}, {'apartment_name': '반포(주공3)', 'road_name': [], 'road_number': []}, {'apartment_name': '삼호가든맨션(1,2차)', 'road_name': [], 'road_number': []}, {'apartment_name': '한신1차', 'road_name': ['한글비석로46가길', '신반포로15길'], 'road_number': ['16', '19']}, {'apartment_name': '금호', 'road_name': ['강서로37길', '공원로', '뚝섬로5길', '동소문로43길'], 'road_number': ['71', '26', '17', '33']}, {'apartment_name': '롯데캐슬쥬피터', 'road_name': ['서운로6길'], 'road_number': ['15-20', '15-13']}, {'apartment_name': '롯데캐슬클래식', 'road_name': ['서운로'], 'road_number': ['197', '200']}, {'apartment_name': '삼호1차', 'road_name': ['서운로'], 'road_number': ['221', '208', '211']}, {'apartment_name': '서초한신', 'road_name': ['남부순환로323길'], 'road_number': ['38-16', '38-15']}, {'apartment_name': '세종', 'road_name': ['독산로50다길', '세종대로23길'], 'road_number': ['22', '54']}, {'apartment_name': '대림', 'road_name': ['남부순환로365길', '공항대로39길', '공항대로75길', '동일로221길', '답십리로60길', '연희로32길', '바우뫼로7길', '잠원로8길', '송이로', '양재대로', '위례성대로', '마천로7길', '신목로5길', '이촌로2가길', '신반포로', '동일로', '논현로41길'], 'road_number': ['16', '100', '42', '22', '38', '20', '51', '88', '1109', '176', '4', '9', '122', '45', '1473', '25', '10']}, {'apartment_name': '옥수하이츠', 'road_name': ['한림말길'], 'road_number': ['48', '50']}, {'apartment_name': '문화', 'road_name': [], 'road_number': []}, {'apartment_name': '반도1차', 'road_name': [], 'road_number': []}, {'apartment_name': 'A파크', 'road_name': [], 'road_number': []}, {'apartment_name': '목동신시가지7', 'road_name': ['목동로'], 'road_number': ['212', '186']}, {'apartment_name': '평화', 'road_name': ['퇴계로8길'], 'road_number': ['23']}, {'apartment_name': '옥인시민', 'road_name': [], ' ...

# %%
# 한번에 처리할 수 있는 값들과 처리할 수 없는 값들 구분하여서 리스트로 추가
process_list2 = list() # 한번에 처리할 수 있는 값들 리스트
process_list3 = list() # 한번에 처리할 수 없는 값들 리스트 - 여러개의 값
process_list4 = list() # 한번에 처리할 수 없는 값들 리스트 - 빈값
for process in process_list:
    temp_dict =dict()
    if (len(process['road_name'])==1) and (len(process['road_number'])==1):
        temp_dict['apartment_name'] = process['apartment_name']
        temp_dict['road_name'] = process['road_name'][0]
        temp_dict['road_number'] = process['road_number'][0]
        process_list2.append(temp_dict)
    elif (process['road_name']==[]) and (process['road_number']==[]):
        process_list4.append(process)
    else:
        process_list3.append(process)
print(process_list2)
# Out:
# [{'apartment_name': '경복', 'road_name': '언주로', 'road_number': '604'}, {'apartment_name': '청실1', 'road_name': '남부순환로395길', 'road_number': '11'}, {'apartment_name': '청실2', 'road_name': '남부순환로395길', 'road_number': '12'}, {'apartment_name': '도곡쌍용예가', 'road_name': '남부순환로363길', 'road_number': '30'}, {'apartment_name': '현대(고덕)', 'road_name': '동남로71길', 'road_number': '41'}, {'apartment_name': '유원강변', 'road_name': '노량진로23가길', 'road_number': '20'}, {'apartment_name': '평화', 'road_name': '퇴계로8길', 'road_number': '23'}, {'apartment_name': '삼익대청아파트', 'road_name': '개포로109길', 'road_number': '21'}, {'apartment_name': '주풍그린빌라트', 'road_name': '명일로', 'road_number': '158-5'}, {'apartment_name': '현대사원', 'road_name': '개포로110길', 'road_number': '46'}, {'apartment_name': '삼익그린2차', 'road_name': '고덕로', 'road_number': '210'}, {'apartment_name': '상계주공16(고층)', 'road_name': '동일로227길', 'road_number': '86'}, {'apartment_name': '한신4차', 'road_name': '동일로230길', 'road_number': '63'}, {'apartment_name': '에이아이디차관주택', 'road_name': '신반포로', 'road_number': '32'}, {'apartment_name': '동신(바동)', 'road_name': '남부순환로363길', 'road_number': '30'}, {'apartment_name': '삼성3차', 'road_name': '도곡로78길', 'road_number': '13'}, {'apartment_name': '신내 데시앙포레', 'road_name': '신내역로', 'road_number': '165'}, {'apartment_name': '신내우디안1단지', 'road_name': '신내역로1길', 'road_number': '85'}, {'apartment_name': '강남한신휴플러스6단지', 'road_name': '밤고개로26길', 'road_number': '50'}, {'apartment_name': '강남한신휴플러스8단지', 'road_name': '밤고개로27길', 'road_number': '20'}, {'apartment_name': '보문하우스토리', 'road_name': '인촌로2길', 'road_number': '37'}, {'apartment_name': '래미안첼리투스아파트', 'road_name': '이촌로', 'road_number': '310'}, {'apartment_name': '풍성애뜨란아파트', 'road_name': '공항대로51길', 'road_number': '23'}, {'apartment_name': '다청림라인씨티', 'road_name': '승방4길', 'road_number': '20'}, {'apartment_name': '상도파크자이', 'road_name': '장승배기로11가길', 'road_number': '11'}, {'apartment_name': 'DMC파크뷰자이1단지', 'road_name': '가재울미래로', 'road_number': '2'}, {'apartment_name': '쌍용대치아파트1동,2동,3동,5동,6동', 'road_name': '영동대로', 'road_number': '210'}, {'apartment_name': '강남엘에이치1단지', 'road_name': '헌릉로571길', 'road_number': '20'}, {'apartment_name': '강남한양수자인(4단지)', 'road_name': '자곡로', 'road_number': '260'}, {'apartment_name': '래미안힐스테이트고덕', 'road_name': '아리수로50길', 'road_number': '50'}, {'apartment_name': '방화5', 'road_name': '금낭화로', 'road_number': '287-19'}, {'apartment_name': '관악동부센트레빌', 'road_name': '은천로33길', 'road_number': '5'}, {'apartment_name': '관악푸르지오102동', 'road_name': '관악로30길', 'road_number': '27'}, {'apartment_name': '이좋은집', 'road_name': '경인로20나길', 'road_number': '30'}, {'apartment_name': '마포센트럴아이파크', 'road_name': '마포대로', 'road_number': '246'}, {'apartment_name': '성원쌍떼빌팰리스', 'road_name': '연희로28길', 'road_number': '35-28'}, {'apartment_name': '서리풀e편한세상', 'road_name': '효령로33길', 'road_number': '50'}, {'apartment_name': '옥수파크힐스101동~116동', 'road_name': '매봉길', 'road_number': '50'}, {'apartment_name': '센트라스', 'road_name': '왕십리로', 'road_number': '410'}, {'apartment_name': '왕십리자이', 'road_name': '난계로', 'road_number': '100'}, {'apartment_name': '보문파크뷰자이', 'road_name': '보문사길', 'road_number': '111'}, {'apartment_name': '동관아트빌', 'road_name': '인촌로12길', 'road_number': '38'}, {'apartment_name': '동아쉐르빌', 'road_name': '인촌로12길', 'road_number': '64'}, {'apartment_name': '마천금호어울림1차아파트', 'road_name': '성내천로', 'road_number': '245'}, {'apartment_name': '문정대우푸르지오1차', 'road_name': '문정로', 'road_number': '55'}, {'apartment_name': '대우레이크월드', 'road_name': '석촌호수로', 'road_number': '298'}, {'apartment_name': '우림', 'road_name': '절골10길', 'road_number': '10'}, {'apartment_name': '형미그린(758-0)', 'road_name': '은평로16가길', 'road_number': '20-3'}, {'apartment_name': '박석고개1단지힐스테이트(101~111동)BL2-12', 'road_name': '진관1로', 'road_number': '21-9'}, {'apartment_name': '청운현대', 'road_name': '자하문로33길', 'road_number': '43'}, {'apartment_name': '용마금호타운', 'road_name': '용마산로', 'road_number': '348'}, {'apartment_name': '당산롯데캐슬프레스티지', 'road_name': '영신로', 'road_number': '237'}, {'apartment_name': '서울역한라비발디센트럴', 'road_name': '만리재로', 'r ...

# %%
# 한번에 처리할 수 있는 값들 데이터프레임 처리
for process in process_list2:
    df.loc[df['name']==process['apartment_name'], 'road_name']=process['road_name']
    df.loc[df['name']==process['apartment_name'], 'road_number']=process['road_number']

# %%
print(len(process_list3)) # 총 41개의 값들 추가적으로 수정 필요
for temp_dict in process_list3: # 수정할 값들의 아파트명 확인
    print(temp_dict)
    print()
# Out:
# 41
# {'apartment_name': '진달래', 'road_name': ['도곡로', '청구로3길'], 'road_number': ['320', '72']}
#
# {'apartment_name': '성보', 'road_name': ['선릉로85길', '테헤란로52길', '목동중앙서로'], 'road_number': ['18', '16', '47']}
#
# {'apartment_name': '한양', 'road_name': ['동남로71길', '미성5길', '구의강변로', '시흥대로', '동일로216길', '서초중앙로', '잠원로', '삼전로4길', '영등포로86길', '국제금융로'], 'road_number': ['19', '33', '11', '165', '92', '220', '62', '4-28', '32', '79']}
#
# {'apartment_name': '삼익가든', 'road_name': ['상암로'], 'road_number': ['224', '225']}
#
# {'apartment_name': '미주', 'road_name': ['성내로', '등촌로13자길', '약령시로', '모래내로', '신반포로16길', '필동로5길'], 'road_number': ['74', '51', '154', '147', '344-7', '15-20', '2']}
#
# {'apartment_name': '성내1차e-편한세상', 'road_name': ['천호대로168길'], 'road_number': ['58', '51']}
#
# {'apartment_name': '현대', 'road_name': ['선릉로18길', '천호옛12길', '공항대로45길', '방화대로37길', '대학20길', '개봉로20길', '구로중앙로18길', '석계로', '섬밭로', '한천로58길', '정릉천동로', '약령시로21길', '서울시립대로29길', '여의대방로26길', '사당로17길', '여의대방로', '토정로', '성암로7길', '충정로7길', '신반포로3길', '동산로6길', '잠원로12길', '마장로35길', '독서당로40길', '송이로34길', '오금로32길', '백제고분로18길', '목동동로', '신목로', '통일로', '다산로36길', '봉우재로57길', '용마산로', '살곶이길'], 'road_number': ['12', '27', '24', '26', '35', '6', '68', '49', '232', '107', '90', '30', '62', '45', '111', '28', '242', '3', '14', '19', '4', '76', '25', '42', '7', '202', '23', '246-20', '246-9', '109', '37-4', '252', '50']}
#
# {'apartment_name': '한신1차', 'road_name': ['한글비석로46가길', '신반포로15길'], 'road_number': ['16', '19']}
#
# {'apartment_name': '금호', 'road_name': ['강서로37길', '공원로', '뚝섬로5길', '동소문로43길'], 'road_number': ['71', '26', '17', '33']}
#
# {'apartment_name': '롯데캐슬쥬피터', 'road_name': ['서운로6길'], 'road_number': ['15-20', '15-13']}
#
# {'apartment_name': '롯데캐슬클래식', 'road_name': ['서운로'], 'road_number': ['197', '200']}
#
# {'apartment_name': '삼호1차', 'road_name': ['서운로'], 'road_number': ['221', '208', '211']}
#
# {'apartment_name': '서초한신', 'road_name': ['남부순환로323길'], 'road_number': ['38-16', '38-15']}
#
# {'apartment_name': '세종', 'road_name': ['독산로50다길', '세종대로23길'], 'road_number': ['22', '54']}
#
# {'apartment_name': '대림', 'road_name': ['남부순환로365길', '공항대로39길', '공항대로75길', '동일로221길', '답십리로60길', '연희로32길', '바우뫼로7길', '잠원로8길', '송이로', '양재대로', '위례성대로', '마천로7길', '신목로5길', '이촌로2가길', '신반포로', '동일로', '논현로41길'], 'road_number': ['16', '100', '42', '22', '38', '20', '51', '88', '1109', '176', '4', '9', '122', '45', '1473', '25', '10']}
#
# {'apartment_name': '옥수하이츠', 'road_name': ['한림말길'], 'road_number': ['48', '50']}
#
# {'apartment_name': '목동신시가지7', 'road_name': ['목동로'], 'road_number': ['212', '186']}
#
# {'apartment_name': '삼성', 'road_name': ['남부순환로379길', '광평로31길', '개포로124길', '도봉로98길', '화곡로61길', '국회대로7길', '은천로', '중계로14나길', '동작대로35아길', '도화길', '마장로', '독서당로', '한천로68길', '백제고분로28길', '문정로', '신월로10길', '국회대로8길', '여의대방로', '평창문화로', '청구로1길', '중랑역로', '동일로236길', '버드나루로14가길', '난곡로63길'], 'road_number': ['14', '27', '33', '49', '101', '46', '25', '28', '32', '271', '218', '51', '36-15', '197', '16', '8', '45', '172', '23', '279', '42', '171', '26']}
#
# {'apartment_name': '현대아파트1동~3동', 'road_name': ['도곡로18길'], 'road_number': ['35', '34']}
#
# {'apartment_name': '태영', 'road_name': ['양천로', '공항대로61길', '곰달래로22길', '신림로', '망원로'], 'road_number': ['590', '60', '9', '350', '61-1']}
#
# {'apartment_name': '워커힐일신', 'road_name': ['아차산로78길'], 'road_number': []}
#
# {'apartment_name': '우성', 'road_name': ['강남대로120길', '양재대로113길', '구천면로', '화곡로68길', '고척로19길', '독산로40길', '섬밭로', '만양로8길', '삼개로', '바우뫼로', '신반포로23길', '성수일로11길', '송파대로32길', '올림픽로43길', '목동중앙로', '이촌로', '가좌로7나길', '동일로149길', '중랑역로', '강서로17나길'], 'road_number': ['58', '50', '366', '103', '115', '69-6', '97', '232', '33', '38', '91', '5', '9', '8', '30', '143', '193', '15', '150', '33-17']}
#
# {'apartment_name': '현대아이파크', 'road_name': ['공항대로', '효령로68길', '동일로157길', '중랑천로'], 'road_number': ['637', '33', '70', '286', '38']}
#
# {'apartment_name': '극동그린', 'road_name': ['독서당로'], 'road_number': ['175', '173']}
#
# {'apartment_name': '호수임광', 'road_name': ['송파대로48길'], 'road_number': ['34', '29']}
#
# {'apartment_name': '개포주공1단지', 'road_name': ['개포로', '선릉로'], 'road_number': ['310', '7']}
#
# {'apartment_name': '상계1차현대아파트', 'road_name': ['동일로237길'], 'road_number': ['41', '37']}
#
# {'apartment_name': '임광', 'road_name': ['등촌로', '노원로', '동교로', '방배로'], 'road_number': ['113', '569', '291', '14']}
#
# {'apartment_name': '태양', 'road_name': ['미성길', '도림로14길', '성대로6가길'], 'road_number': ['59', '11-1', '100']}
#
# {'apartment_name': '반포주공1단지', 'road_name': ['신반포로'], 'road_number': ['45', '9']}
#
# {'apartment_name': '삼호가든맨션(4차)', 'road_name': ['사평대로', '고무래로'], 'road_number': ['310-8', '79']}
#
# {'apartment_name': '우성아파트', 'road_name': ['서초대로74길', '올림픽로4길', '삼성로147길'], 'road_number': ['30', '42', '22']}
#
# {'apartment_name': '엘지,쌍용아파트', 'road_name': ['봉화산로'], 'road_number': ['146', '130']}
#
# {'apartment_name': '진로아파트', 'road_name': ['신내로17길'], 'road_number': ['41', '39']}
#
# {'apartment_name': '태솔에버빌', 'road_name': ['삼양로80길', '장한로28가길', '망우로26길'], 'road_number': ['55', '91', '8']}
#
# {'apartment_name': '꿈의숲SKVIEW', 'road_name': ['월계로42길'], 'road_number': ['97', '20']}
#
# {'apartment_name': '신반포18(49-17)', 'road_name': ['잠원로', '잠원로12길'], 'road_number': ['195', '5']}
#
# {'apartment_name': '현대3', 'road_name': ['진황도로', '양천로75길', '아차산로70길', '뚝섬로56가길', '뚝섬로58길', '우이천로38가길'], 'road_number': ['211', '60', '62', '10', '101', '32']}
#
# {'apartment_name': '우성아파트1', 'road_name': ['해등로'], 'road_number': ['286-5', '295']}
#
# {'apartment_name': '삼각아파트', 'road_name': ['한강대로62길'], 'road_number': ['32', '26', '18', '174-2']}
#
# {'apartment_name': '안암동삼성래미안', 'road_name': ['인촌로17가길', '고려대로17가길'], 'road_number': ['64']}

# %%
# ''값 처리
# 추가할 값들
# df.loc[(df['name']=='진달래') & (df['address_1']=='강남구') , 'road_name'] = '도곡로'
# df.loc[(df['name']=='진달래') & (df['address_1']=='강남구') , 'road_number'] = '320'

# df.loc[(df['name']=='성보') &  (df['address_2']=='역삼동') , 'road_name'] = '선릉로85길'
# df.loc[(df['name']=='성보') &  (df['address_2']=='역삼동') , 'road_number'] = '18'

# df.loc[(df['name']=='진달래2차') , 'road_name'] = '도곡로43길'
# df.loc[(df['name']=='진달래2차') , 'road_number'] = '21'

# df.loc[(df['name']=='진달래3차') , 'road_name'] = '도곡로43길'
# df.loc[(df['name']=='진달래3차') , 'road_number'] = '20'
# 제거할 값들

# %%
# 체크1
df.loc[(df['name']== '서초한신') &  ((df['road_name']=='')|(df['road_number']=='')) , :]
# Out:
#             date address_1 address_2  road_name road_number  floor  \
# 79974 2006-10-19       서초구       서초동  남부순환로323길                  7
# 79975 2006-10-24       서초구       서초동  남부순환로323길                  3
# 40988 2007-06-29       서초구       서초동  남부순환로323길                  9
# 40989 2007-07-17       서초구       서초동  남부순환로323길                  5
# 40990 2007-08-06       서초구       서초동  남부순환로323길                  6
# 40991 2007-08-06       서초구       서초동  남부순환로323길                 10
# 37331 2008-01-21       서초구       서초동  남부순환로323길                 10
#
#        deal_price  name
# 79974       75800  서초한신
# 79975       67800  서초한신
# 40988       63200  서초한신
# 40989       79200  서초한신
# 40990       75000  서초한신
# 40991      110000  서초한신
# 37331       68000  서초한신

# %%
# 체크2
df.loc[(df['name']== '서초한신'), :]
# Out:
#             date address_1 address_2  road_name road_number  floor  \
# 79959 2006-03-08       서초구       서초동  남부순환로323길       38-16      8
# 79960 2006-03-11       서초구       서초동  남부순환로323길       38-16      7
# 79961 2006-03-14       서초구       서초동  남부순환로323길       38-16      8
# 79962 2006-03-15       서초구       서초동  남부순환로323길       38-15     12
# 79963 2006-03-24       서초구       서초동  남부순환로323길       38-16      3
# ...          ...       ...       ...        ...         ...    ...
# 54135 2020-10-21       서초구       서초동  남부순환로323길       38-15      4
# 27480 2021-05-22       서초구       서초동  남부순환로323길       38-16      6
# 27481 2021-09-18       서초구       서초동  남부순환로323길       38-15     10
# 27482 2021-09-25       서초구       서초동  남부순환로323길       38-16      2
# 7959  2022-04-05       서초구       서초동  남부순환로323길       38-16      3
#
#        deal_price  name
# 79959       68500  서초한신
# 79960       69000  서초한신
# 79961       83000  서초한신
# 79962       88000  서초한신
# 79963       54500  서초한신
# ...           ...   ...
# 54135      158000  서초한신
# 27480      186700  서초한신
# 27481      182000  서초한신
# 27482      189000  서초한신
# 7959       190500  서초한신
#
# [143 rows x 8 columns]

# %%
# 체크3
df.loc[(df['name']=='한양') & (df['address_2']=='명일동'), :]
# Out:
#             date address_1 address_2 road_name road_number  floor  deal_price  \
# 11060 2006-01-04       강동구       명일동    동남로71길          19     13       80000
# 11061 2006-01-07       강동구       명일동    동남로71길                 13       69900
# 11062 2006-01-12       강동구       명일동    동남로71길                  8       68000
# 11063 2006-01-16       강동구       명일동    동남로71길                  2       66000
# 11064 2006-01-18       강동구       명일동    동남로71길          19      3       46500
# ...          ...       ...       ...       ...         ...    ...         ...
# 3156  2021-03-03       강동구       명일동    동남로71길          19      4      170000
# 3157  2021-03-11       강동구       명일동    동남로71길          19     11      147000
# 3158  2021-03-12       강동구       명일동    동남로71길          19      1      170500
# 3159  2021-08-06       강동구       명일동    동남로71길          19      5      171500
# 3160  2021-10-08       강동구       명일동    동남로71길          19     14      160000
#
#       name
# 11060   한양
# 11061   한양
# 11062   한양
# 11063   한양
# 11064   한양
# ...    ...
# 3156    한양
# 3157    한양
# 3158    한양
# 3159    한양
# 3160    한양
#
# [420 rows x 8 columns]

# %%
df.loc[(df['address_2']=='옥수동') & (df['road_name']=='한림말길'), :]
# Out:
#             date address_1 address_2 road_name road_number  floor  deal_price  \
# 84498 2006-04-10       성동구       옥수동      한림말길          24      7       31000
# 84499 2006-04-28       성동구       옥수동      한림말길          24      6       31500
# 84500 2006-09-04       성동구       옥수동      한림말길          24      1       18000
# 84501 2006-10-09       성동구       옥수동      한림말길          24     12       35500
# 84502 2006-10-24       성동구       옥수동      한림말길          24      2       29800
# ...          ...       ...       ...       ...         ...    ...         ...
# 29179 2021-10-09       성동구       옥수동      한림말길          50      3      184000
# 29180 2021-10-10       성동구       옥수동      한림말길          50     11      190000
# 29181 2021-11-22       성동구       옥수동      한림말길          50     15      213000
# 8369  2022-05-19       성동구       옥수동      한림말길          50     13      220000
# 8370  2022-12-24       성동구       옥수동      한림말길          50     12      163000
#
#         name
# 84498   극동옥정
# 84499   극동옥정
# 84500   극동옥정
# 84501   극동옥정
# 84502   극동옥정
# ...      ...
# 29179  옥수하이츠
# 29180  옥수하이츠
# 29181  옥수하이츠
# 8369   옥수하이츠
# 8370   옥수하이츠
#
# [463 rows x 8 columns]

# %% [markdown]
# road_name 까지만 해서 가격들이 비슷하게 움직인다면, road_number까지는 하지 말자?
# 2011년 부터 자료 모으기 시작?, 값들이 비어있는 프레임들의 날짜가 2010년 이전인듯
